# %% [markdown]
# <a href="https://colab.research.google.com/github/lauramendescd/Redes_Neurais/blob/main/Water_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###QUESTÃO 01

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('waterQuality1.csv')
data.head(7)
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
# 5       0.94   14.47     0.03    2.88    0.003        0.80      0.43    1.38
# 6       2.36     5.6     0.01    1.35    0.004        1.28      0.62    1.88
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
data.describe()
# Out:
#          aluminium      arsenic       barium      cadmium   chloramine  \
# count  7999.000000  7999.000000  7999.000000  7999.000000  7999.000000
# mean      0.666158     0.161445     1.567715     0.042806     2.176831
# std       1.265145     0.252590     1.216091     0.036049     2.567027
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.040000     0.030000     0.560000     0.008000     0.100000
# 50%       0.070000     0.050000     1.190000     0.040000     0.530000
# 75%       0.280000     0.100000     2.480000     0.070000     4.240000
# max       5.050000     1.050000     4.940000     0.130000     8.680000
#
#           chromium       copper     flouride     bacteria      viruses  \
# count  7999.000000  7999.000000  7999.000000  7999.000000  7999.000000
# mean      0.247226     0.805857     0.771565     0.319665     0.328583
# std       0.270640     0.653539     0.435373     0.329485     0.378096
# ...

# %%
dados = data.dropna()
dados
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
dados1 = dados[dados["nitrates"]>= 10.0]
dados1
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 6          2.36     5.6     0.01    1.35    0.004        1.28      0.62
# 7          3.93   19.87     0.04    0.66    0.001        6.22      0.10
# 8          0.60   24.58     0.01    0.71    0.005        3.14      0.77
# ...         ...     ...      ...     ...      ...         ...       ...
# 7993       0.02    5.24     0.05    0.77    0.020        0.57      0.04
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
df = dados.drop(["aluminium", "arsenic", "barium", "cadmium", "chloramine", "chromium", "copper", "flouride", "lead", "mercury", "radium", "selenium", "silver", "uranium"], axis=1)
df.dropna()
# Out:
#      ammonia  bacteria  viruses  nitrates  nitrites  perchlorate is_safe
# 0       9.08      0.20    0.000     16.08      1.13        37.75       1
# 1      21.16      0.65    0.650      2.01      1.93        32.26       1
# 2      14.02      0.05    0.003     14.16      1.11        50.28       0
# 3      11.33      0.71    0.710      1.41      1.29         9.12       1
# 4      24.33      0.13    0.001      6.74      1.11        16.90       1
# ...      ...       ...      ...       ...       ...          ...     ...
# 7994    7.78      0.00    0.000     14.29      1.00         3.57       1
# 7995   24.22      0.00    0.000     10.27      1.00         1.48       1
# 7996    6.85      0.00    0.000     15.92      1.00         1.35       1
# 7997      10      0.00    0.000      0.00      0.00         0.00       1
# 7998    6.85      0.00    0.000     15.92      1.00         1.35       1
#
# [7999 rows x 7 columns]

# %% [markdown]
# ###QUESTÃO 02

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
from sqlalchemy import String
from IPython.utils.text import string
X = np.array(df.iloc[:, 0:12]) 	# features
y = np.array(df['is_safe']) 	    # classes
X_train, X_test, y_train, y_test = train_test_split(X,y,stratify=y,random_state=42)

# %%
print(X.shape,y.shape)
# Out:
# (7999, 7) (7999,)

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-86937c1966f0> in <cell line: 1>()
# ----> 1 clf.fit(X_train,y_train)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
#     455                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     456                 )
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

X = df[('ammonia','bacteria','viruses','nitrates','nitrites','perchlorate')].values
y = df['df'].values
print(X.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-c702a2684fec> in <cell line: 3>()
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2
# ----> 3 X = df[('ammonia','bacteria','viruses','nitrates','nitrites','perchlorate')].values
#       4 y = df['df'].values
#       5 print(X.shape, y.shape)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
